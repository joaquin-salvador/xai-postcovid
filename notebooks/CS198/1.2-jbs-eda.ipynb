# %% [markdown]
# # CS 198/199
# # Joaquin B. Salvador
# # Explainable AI for Post-COVID Psychological Profile Prediction
#
# ## 1.2
# ### Statistical Tests

# %% [markdown]
# "I think the mode is not that informative when it comes to significant differences. Based on the scatterplots, there were still some people with +/- changes.
#
# You could use statistical testing instead (perhaps Wilcoxon signed-rank test, para no normal distribution assumption).
# I also suggest using bubble plot instead of scatter plots, since may mga overlapping points, and hindi obvious based on the transparency lang:
#
# https://plotly.com/python/bubble-charts/#:~:text=A%20bubble%20chart%20is%20a,see%20the%20scatter%20plot%20documentation."

# %%
# Import
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pd.options.display.max_rows = 1000
df = pd.read_csv('..\\data\\interim\\dataset_differences.csv')

# %%
df.head()

# %%
# K6
X = np.array(df.K6_total_old)
Y = np.array(df.K6_total_new)
res = stats.wilcoxon(X, Y, alternative='two-sided')
res

# %%
# K6
X = np.array(df.K6_total_old)
Y = np.array(df.K6_total_new)
res = stats.wilcoxon(X, Y, alternative='greater')
res

# %%
# K6
X = np.array(df.K6_total_old)
Y = np.array(df.K6_total_new)
res = stats.wilcoxon(X, Y, alternative='less')
res

# %%
#  PHQ9
X = np.array(df.PHQ9_total_old)
Y = np.array(df.PHQ9_total_new)
res = stats.wilcoxon(X, Y, alternative='two-sided')
res

# %%
#  PHQ9
X = np.array(df.PHQ9_total_old)
Y = np.array(df.PHQ9_total_new)
res = stats.wilcoxon(X, Y, alternative='greater')
res

# %%
#  PHQ9
X = np.array(df.PHQ9_total_old)
Y = np.array(df.PHQ9_total_new)
res = stats.wilcoxon(X, Y, alternative='less')
res

# %%
#  GAD7
X = np.array(df.GAD7_total_old)
Y = np.array(df.GAD7_total_new)
res = stats.wilcoxon(X, Y, alternative='two-sided')
res

# %%
#  GAD7
X = np.array(df.GAD7_total_old)
Y = np.array(df.GAD7_total_new)
res = stats.wilcoxon(X, Y, alternative='greater')
res

# %%
#  GAD7
X = np.array(df.GAD7_total_old)
Y = np.array(df.GAD7_total_new)
res = stats.wilcoxon(X, Y, alternative='less')
res

# %%
#  SSS8
X = np.array(df.SSS8_total_old)
Y = np.array(df.SSS8_total_new)
res = stats.wilcoxon(X, Y, alternative='two-sided')
res

# %%
#  SSS8
X = np.array(df.SSS8_total_old)
Y = np.array(df.SSS8_total_new)
res = stats.wilcoxon(X, Y, alternative='greater')
res

# %%
#  SSS8
X = np.array(df.SSS8_total_old)
Y = np.array(df.SSS8_total_new)
res = stats.wilcoxon(X, Y, alternative='less')
res

# %%
#  LSNS
X = np.array(df.LSNS6_total_old)
Y = np.array(df.LSNS6_total_new)
res = stats.wilcoxon(X, Y, alternative='two-sided')
res

# %%
#  LSNS
X = np.array(df.LSNS6_total_old)
Y = np.array(df.LSNS6_total_new)
res = stats.wilcoxon(X, Y, alternative='greater')
res

# %%
#  LSNS
X = np.array(df.LSNS6_total_old)
Y = np.array(df.LSNS6_total_new)
res = stats.wilcoxon(X, Y, alternative='less')
res

# %%
#  ucla
X = np.array(df.UCLA_total_old)
Y = np.array(df.UCLA_total_new)
res = stats.wilcoxon(X, Y, alternative='two-sided')
res

# %%
#  ucla
X = np.array(df.UCLA_total_old)
Y = np.array(df.UCLA_total_new)
res = stats.wilcoxon(X, Y, alternative='greater')
res

# %%
#  ucla
X = np.array(df.UCLA_total_old)
Y = np.array(df.UCLA_total_new)
res = stats.wilcoxon(X, Y, alternative='less')
res

# %%
#  SHS
X = np.array(df.SHS_total_old)
Y = np.array(df.SHS_total_new)
res = stats.wilcoxon(X, Y, alternative='two-sided')
res

# %%
#  SHS
X = np.array(df.SHS_total_old)
Y = np.array(df.SHS_total_new)
res = stats.wilcoxon(X, Y, alternative='greater')
res

# %%
#  SHS
X = np.array(df.SHS_total_old)
Y = np.array(df.SHS_total_new)
res = stats.wilcoxon(X, Y, alternative='less')
res
